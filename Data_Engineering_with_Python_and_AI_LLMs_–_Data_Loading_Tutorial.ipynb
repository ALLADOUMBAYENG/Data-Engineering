# %% [markdown]
# <a href="https://colab.research.google.com/github/ALLADOUMBAYENG/Data-Engineering/blob/main/Data_Engineering_with_Python_and_AI_LLMs_%E2%80%93_Data_Loading_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Extract Data**

# %%
import requests

url = "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events"

response = requests.get(url)

response.json()
# Out:
# [{'id': '54195454185',
#   'type': 'WatchEvent',
#   'actor': {'id': 67962053,
#    'login': 'ABRSO',
#    'display_login': 'ABRSO',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ABRSO',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67962053?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-09-03T13:31:16Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '54194696129',
#   'type': 'WatchEvent',
#   'actor': {'id': 34588295,
#    'login': 'ZoeyKu',
#    'display_login': 'ZoeyKu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ZoeyKu',
# ...

# %% [markdown]
# **Add Time**

# %%
import time

url = "https://api.github.com/rate_limit"

response = requests.get(url)
response.json()
# Out:
# {'resources': {'code_search': {'limit': 60,
#    'remaining': 59,
#    'reset': 1756951858,
#    'used': 1,
#    'resource': 'code_search'},
#   'core': {'limit': 60,
#    'remaining': 59,
#    'reset': 1756951858,
#    'used': 1,
#    'resource': 'core'},
#   'graphql': {'limit': 0,
#    'remaining': 0,
#    'reset': 1756952456,
#    'used': 0,
#    'resource': 'graphql'},
#   'integration_manifest': {'limit': 5000,
#    'remaining': 5000,
#    'reset': 1756952456,
#    'used': 0,
#    'resource': 'integration_manifest'},
#   'search': {'limit': 10,
#    'remaining': 10,
#    'reset': 1756948916,
#    'used': 0,
#    'resource': 'search'}},
#  'rate': {'limit': 60,
#   'remaining': 59,
#   'reset': 1756951858,
#   'used': 1,
#   'resource': 'core'}}

# %%
import time

url = "https://api.github.com/rate_limit"

requests.get(url).json()
# Out:
# {'resources': {'code_search': {'limit': 60,
#    'remaining': 59,
#    'reset': 1756951858,
#    'used': 1,
#    'resource': 'code_search'},
#   'core': {'limit': 60,
#    'remaining': 59,
#    'reset': 1756951858,
#    'used': 1,
#    'resource': 'core'},
#   'graphql': {'limit': 0,
#    'remaining': 0,
#    'reset': 1756952621,
#    'used': 0,
#    'resource': 'graphql'},
#   'integration_manifest': {'limit': 5000,
#    'remaining': 5000,
#    'reset': 1756952621,
#    'used': 0,
#    'resource': 'integration_manifest'},
#   'search': {'limit': 10,
#    'remaining': 10,
#    'reset': 1756949081,
#    'used': 0,
#    'resource': 'search'}},
#  'rate': {'limit': 60,
#   'remaining': 59,
#   'reset': 1756951858,
#   'used': 1,
#   'resource': 'core'}}

# %%
import time

url = "https://api.github.com/rate_limit"

remaining = requests.get(url).json()['rate']['remaining']
if remaining ==0:
  time.sleep(30)

# %% [markdown]
# **2. Authentication**
#
# ```
# # Many APIs require an API key token to access data securely. Without authnetication, requests may be limited or denied. ```

# %%
url = "https://api.github.com/user"
requests.get(url).json()
# Out:
# {'message': 'Requires authentication',
#  'documentation_url': 'https://docs.github.com/rest/users/users#get-the-authenticated-user',
#  'status': '401'}

# %%
from google.colab import userdata
API_TOKEN = userdata.get(ACCESS_TOKEN)

headers = {
    "Authentication": f"Bearer (API_TOKEN)"
}

requests.get(url, headers=headers).json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3804458216.py in <cell line: 0>()
#       1 from google.colab import userdata
# ----> 2 API_TOKEN = userdata.get(ACCESS_TOKEN)
#       3
#       4 headers = {
#       5     "Authentication": f"Bearer (API_TOKEN)"
#
# NameError: name 'ACCESS_TOKEN' is not defined

# %%
import requests

url= "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events?page=9"

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.headers['Link']
# Out:
# '<https://api.github.com/repositories/419661684/events?page=8>; rel="prev", <https://api.github.com/repositories/419661684/events?page=10>; rel="next", <https://api.github.com/repositories/419661684/events?page=10>; rel="last", <https://api.github.com/repositories/419661684/events?page=1>; rel="first"'

# %%
response.links['next']['url']
# Out:
# 'https://api.github.com/repositories/419661684/events?page=10'

# %%
url= "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events"

while True:
  response = requests.get(url)
  data = response.json()
  print(len(data))

  if 'next' not in response.links:
    break

    url = response.links['next']['url']
# Out:
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 2
